# %% [markdown]
# 1. What exactly is []?
# Ans - list
#
# 2. In a list of values stored in a variable called spam, how would you assign the value 'hello' as the third value? (Assume [2, 4, 6, 8, 10] are in spam.)
# Ans - spam.append("hello")
#
#
# # Let's pretend the spam includes the list ['a', 'b', 'c', 'd'] for the next three queries.
#
# 3. What is the value of spam[int(int('3' * 2) / 11)]?
# Ans - 'd'
#
# 4. What is the value of spam[-1]?
# Ans - 'd'
#
#
# 5. What is the value of spam[:2]?
# Ans - ['a','b']
#
#
# # let's pretend bacon has the list [3.14, 'cat,' 11, 'cat,' True] for the next three questions.
#
# i'm considering this - [3.14, 'cat', 11, 'cat', True]
# 6. What is the value of bacon.index('cat')?
# Ans - 1
#
# 7. How does bacon.append(99) change the look of the list value in bacon?
# Ans - [3.14, 'cat', 11, 'cat', True, 99]
#
#
# 8. How does bacon.remove('cat') change the look of the list in bacon?
# Ans - [3.14, 11, 'cat', True, 99]
#
#
# 9. What are the list concatenation and list replication operators?
# Ans -
# a. concatination - The '+' operator is used to concatenate (combine) two or more lists into a single list.
#  ex -
#     l1 = [1,2,3,"elon"]
#     l2 = ['musk','is','obsessed','with','his past ', 'X']
#     l3 = l1 + l2
#     l3
#
# b. replication - The * operator is used to replicate the all elements present inside a list .
#  ex -
#  l2 = ["am", "i" ,"preparing" ,"for" ,"job"]*2
#  l2
# 10. What is difference between the list methods append() and insert()?
# Ans - append() - inserts objects at the last index
#       insert() - inserts objects at the specified index as it two arguments.
#
#
# 11. What are the two methods for removing items from a list?
# Ans - pop() and remove()
#
#
# 12. Describe how list values and string values are identical.
# Ans - a.they are both sequential data type.
#       b.they have same method for indexing
#       c.they have some slicing operations
#       d.both can be iterated for example we can use for loop to print all the objects present inside list as well as string
#
#
# 13. What's the difference between tuples and lists?
# Ans - a.tuples are immutable and lists are mutable.
#       b.syntax for tuple - ()
#         syntax for list - []
#       c.the performace of tuple is better since it is immutable thus python can optimize memory usage for tuple.
#       d.gerally lists are used for storing objects where objects can inserted if needed in future or also they deleted on the
#         other hand tuple are used to store objects so that the data remains secure and no modification of that data is                 required.
#
#
# 14. How do you type a tuple value that only contains the integer 42?
# Ans - t = (42)
#
# 15. How do you get a list value's tuple form? How do you get a tuple value's list form?
# Ans - a. tuple(list_variable)
#       b. list(tuple_variable)
#
#
# 16. Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?
# Ans - not able to understand question.
#
#
# 17. How do you distinguish between copy.copy() and copy.deepcopy()?
# Ans - opy.copy(): Creates a shallow copy of the object, retaining references to nested objects and any changes to copyed object will affect the original.
# copy.deepcopy(): Creates a deep copy of the object, recursively duplicating all nested objects for complete independence.it does not the original object. for this new independent object new memory is allocated.
