# %% [markdown]
# 1. What are the two values of the Boolean data type? How do you write them?
# Ans : 1.True
#         ex - x = True
#       2.False
#         ex - f = False
#
# 2. What are the three different types of Boolean operators?
# Ans : 1. and - and operator will return True when operands are True.
#       2. or - or operator will return True if any operand is True.
#       3. not - The not operator returns the opposite Boolean value of the operand.
#
# 3. Make a list of each Boolean operator's truth tables (i.e. every possible combination of Boolean values for the operator and what it evaluate ).
# Ans:
# and truth table:
# True
# False
# False
# False
# **************************************************
# or truth table:
# True
# True
# True
# False
# **************************************************
# not table
# False
# True
#
# 4. What are the values of the following expressions?
# (5 > 4) and (3 == 5)
# not (5 > 4)
# (5 > 4) or (3 == 5)
# not ((5 > 4) or (3 == 5))
# (True and True) and (True == False)
# (not False) or (not True)
# Ans :
#     (5 > 4) and (3 == 5) - False
#     not (5 > 4) - False
#     (5 > 4) or (3 == 5) - True
#     not ((5 > 4) or (3 == 5)) - False
#     (True and True) and (True == False) - False
#     (not False) or (not True) - True
#
# 5. What are the six comparison operators?
# Ans - '>' - greater than
#       '<' - less than
#       '>=' - greater than or equal to
#       '<=' - less than or equal to
#       '==' - equal to
#       '!=' - not equal to
#
#
# 6. How do you tell the difference between the equal to and assignment operators?Describe a condition and when you would use one.
# Ans- for equal to operator we use "=="
#         ex -
#             if a==4:
#                 print("it's equal oparator")
#      for assignment operator we use "="
#          ex -
#              a = 4
#
# 7. Identify the three blocks in this code:
#
#
# spam = 0
# if spam == 10:
# print('eggs')
# if spam > 5:
# print('bacon')
# else:
# print('ham')
# print('spam')
# print('spam')
# Ans -
#         spam = int(input())
#         if spam == 10:
#             print('eggs')
#         elif spam > 5:
#             print('bacon')
#         else:
#             print('ham')
#             print('spam')
#             print('spam')
#
# 8. Write code that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam, and prints Greetings! if anything else is stored in spam.
# Ans -
#         spam = int(input())
#         if spam == 1:
#             print('hello')
#         elif spam == 2:
#             print('Howdy')
#         else:
#             print('Grettings')
#
#
# 9. If your programme is stuck in an endless loop, what keys you’ll press?
# Ans - interrupt the kernel button.
#
#
# 10. How can you tell the difference between break and continue?
# Ans - 1.break - The break statement is used to exit the current loop    prematurely when a specific condition is met.
#       2.continue - The continue statement is used to skip the current iteration of the loop when a specific condition is met.
#
# 11. In a for loop, what is the difference between range(10), range(0, 10), and range(0, 10, 1)?
# Ans - range(10) - strarts from 0(default if not mentioned) and ends upto 10 but not 10 with a step value of 1(default).
#       range(0,10) - strarts from 0 and ends upto 10 but not 10 with a step value of 1(default).
#       range(0, 10, 1) - strarts from 0 and ends upto 10 but not 10 with a step value of 1.
#
#
# 12. Write a short program that prints the numbers 1 to 10 using a for loop. Then write an equivalent program that prints the numbers 1 to 10 using a while loop.
# Ans -
#      1. for loop-
#      for i in range(1,11):
#          print(i)
#      2.while loop-
#         i = 1
#         while i<=10:
#             print(i)
#             i=i+1
#
#
#
# 13. If you had a function named bacon() inside a module named spam, how would you call it after importing spam?
# Ans - import spam as s
#       s.becon()
